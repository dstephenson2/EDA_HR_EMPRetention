# %% [markdown]
# ### EDA_Plots_Practise

# %%
import pandas as pd
import numpy as np
import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sns

# %%
emp_atr = pd.read_csv("HR-Employee-Attrition.csv")

# %%
emp_atr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
emp_atr.shape
# Out:
# (1470, 35)

# %%
emp_atr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
emp_atr.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
miss = emp_atr.isnull().sum()
miss
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
emp_atr['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
emp_atr['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
emp_atr['DistanceFromHome'].unique()
# Out:
# array([ 1,  8,  2,  3, 24, 23, 27, 16, 15, 26, 19, 21,  5, 11,  9,  7,  6,
#        10,  4, 25, 12, 18, 29, 22, 14, 20, 28, 17, 13], dtype=int64)

# %%
emp_atr['Education'].unique()
# Out:
# array([2, 1, 4, 3, 5], dtype=int64)

# %%
emp_atr['RelationshipSatisfaction'].unique()
# Out:
# array([1, 4, 2, 3], dtype=int64)

# %%
emp_atr['WorkLifeBalance'].unique()
# Out:
# array([1, 3, 2, 4], dtype=int64)

# %%
emp_atr.notnull().all()
# Out:
# Age                         True
# Attrition                   True
# BusinessTravel              True
# DailyRate                   True
# Department                  True
# DistanceFromHome            True
# Education                   True
# EducationField              True
# EmployeeCount               True
# EmployeeNumber              True
# EnvironmentSatisfaction     True
# Gender                      True
# HourlyRate                  True
# JobInvolvement              True
# JobLevel                    True
# JobRole                     True
# JobSatisfaction             True
# MaritalStatus               True
# MonthlyIncome               True
# MonthlyRate                 True
# NumCompaniesWorked          True
# Over18                      True
# OverTime                    True
# PercentSalaryHike           True
# PerformanceRating           True
# RelationshipSatisfaction    True
# StandardHours               True
# StockOptionLevel            True
# ...

# %%
profile=pandas_profiling.ProfileReport(emp_atr)
profile.to_file("HR_Emp_Attr_before_processing.html")

# %%
emp_atr['Age'].nunique()
# Out:
# 43

# %%
emp_atr[emp_atr['Attrition']=='No']['Attrition'].count()
# Out:
# 1233

# %%
emp_atr.drop(("EmployeeCount"),axis=1,inplace=True) # emp_atr.drop(['EmployeeCount','StandardHours'],axis=1,inplace=True)
emp_atr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  ... RelationshipSatisfaction  StandardHours  \
# 0                        2  ...                        1             80
# ...

# %%
emp_atr.drop("StandardHours",axis=1,inplace=True)
emp_atr.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  ... PerformanceRating  RelationshipSatisfaction  \
# 0                        2  ...                 3                         1
# ...

# %%
corr = emp_atr.corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr,vmax=0.8,linewidth=.01, square = True, annot = True,cmap='YlGnBu',linecolor ='black')
plt.title('Correlation between features')
# Out:
# Text(0.5, 1.0, 'Correlation between features')

# %%
attr_1 = sns.countplot(x='Attrition',hue='BusinessTravel',data=emp_atr) 
"""Attrition is higher in those travelling rarely than those travelling frequently,
hence Business travel may not be the reason for attrition"""
# Out:
# 'Attrition is higher in those travelling rarely than those travelling frequently,\nhence Business travel may not be the reason for attrition'

# %%
attr_1 = sns.countplot(x='Attrition',hue='Department',data=emp_atr) 
# trend is same in both Yes and No, hence dept may not be major factor

# %%
attr_1 = sns.countplot(x='Attrition',hue='Education',data=emp_atr) # same trend

# %%
attr_1 = sns.countplot(x='Attrition',hue='EducationField',data=emp_atr)

# %%
attr_1 = sns.countplot(x='Attrition',hue='EnvironmentSatisfaction',data=emp_atr) # Corelated, 1 is clearly depicting +ve corr

# %%
attr_1 = sns.countplot(x='Attrition',hue='Gender',data=emp_atr)

# %%
attr_1 = sns.countplot(x='Attrition',hue='JobInvolvement',data=emp_atr)

# %%
attr_1 = sns.countplot(x='Attrition',hue='JobLevel',data=emp_atr) # Highly Corr

# %%
attr_1 = sns.countplot(x='Attrition',hue='JobRole',data=emp_atr) # Corr

# %%
attr_1 = sns.countplot(x='Attrition',hue='JobSatisfaction',data=emp_atr) # -vly Corr

# %%
attr_1 = sns.countplot(x='Attrition',hue='MaritalStatus',data=emp_atr) #

# %%
sns.catplot(x="YearsAtCompany", y="JobSatisfaction", hue="Attrition",
                data=emp_atr, 
                height=4, aspect=.7);
